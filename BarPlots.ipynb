# %% [markdown]
# <a href="https://colab.research.google.com/github/mazidgaba/Data-Visualization/blob/main/BarPlots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/mtcars.csv")

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
sns.regplot(x=df['hp'], y=df['wt'])
# Out:
# <Axes: xlabel='hp', ylabel='wt'>

# %%
sns.regplot(x=df['hp'],fit_reg=False, y=df['wt'])
# Out:
# <Axes: xlabel='hp', ylabel='wt'>

# %%
sns.barplot(df['wt'])
# Out:
# <Axes: ylabel='wt'>

# %%
sns.barplot(df['wt'], kde=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-0c7f6c5fefc1> in <cell line: 1>()
# ----> 1 sns.barplot(df['wt'], kde=True)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2368     saturation = saturation if fill else 1
#    2369     p.map_hue(palette=palette, order=hue_order, norm=hue_norm, saturation=saturation)
# -> 2370     color = _default_color(ax.bar, hue, color, kwargs, saturation=saturation)
#    2371
#    2372     agg_cls = WeightedAggregator if "weight" in p.plot_data else EstimateAggregator
#
# ...

# %%
sns.histplot(df, x="wt")
# Out:
# <Axes: xlabel='wt', ylabel='Count'>

# %%
sns.histplot(df, y="wt")
# Out:
# <Axes: xlabel='Count', ylabel='wt'>

# %%
sns.histplot(df, x="hp")
# Out:
# <Axes: xlabel='hp', ylabel='Count'>

# %%
sns.histplot(df, x="hp", binwidth= 30)
# Out:
# <Axes: xlabel='hp', ylabel='Count'>

# %%
sns.histplot(df, x="hp", kde= True)
# Out:
# <Axes: xlabel='hp', ylabel='Count'>

# %%
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(df, x="hp" , hue="wt")
# Out:
# <Axes: xlabel='hp', ylabel='Count'>

# %%
sns.histplot(df, x="hp" , hue="wt", multiple="stack")
# Out:
# <Axes: xlabel='hp', ylabel='Count'>

# %%
sns.histplot(df, x="hp" , hue="wt", element="step")
# Out:
# <Axes: xlabel='hp', ylabel='Count'>

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(df['hp'])
# Out:
# <Axes: ylabel='hp'>

# %%
sns.distplot(df['hp'])
# Out:
# <ipython-input-36-1482cd2a5986>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['hp'])
# <Axes: xlabel='hp', ylabel='Density'>

# %%
sns.distplot(df['hp'], bins=5)
# Out:
# <ipython-input-37-19e7060e8185>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['hp'], bins=5)
# <Axes: xlabel='hp', ylabel='Density'>

# %%
sns.countplot(df)
# Out:
# <Axes: ylabel='count'>

# %%
sns.pairplot(df)
